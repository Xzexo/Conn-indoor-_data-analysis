# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
all_data=pd.read_csv('all_visitor_from_may_10_to_may_20_.csv')
all_data
# Out:
#                            created_at            item_name     name  \
# 0       2023-05-10 00:00:28.286429+07                 C301  Level 3
# 1       2023-05-10 00:01:28.273742+07                 C301  Level 3
# 2       2023-05-10 00:02:28.229053+07                 C301  Level 4
# 3       2023-05-10 00:03:28.239281+07                 C301  Level 3
# 4       2023-05-10 00:04:28.261325+07                 C301  Level 3
# ...                               ...                  ...      ...
# 314940  2023-05-20 23:55:21.998693+07  แม่บ้านประจำตึก D,E  Level 1
# 314941  2023-05-20 23:56:21.692988+07  แม่บ้านประจำตึก D,E  Level 1
# 314942  2023-05-20 23:57:21.750086+07  แม่บ้านประจำตึก D,E  Level 1
# 314943  2023-05-20 23:58:21.721702+07  แม่บ้านประจำตึก D,E  Level 1
# 314944  2023-05-20 23:59:21.761506+07  แม่บ้านประจำตึก D,E  Level 1
#
#         closest_node_number  radius_meter  node_x  node_y  visitor_x  \
# 0                        31          0.89    8901    2953       8900
# ...
