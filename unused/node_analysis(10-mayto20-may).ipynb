# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
all_data1=pd.read_csv('Visitor(10-may-2023 to 20-may-2023).csv')

print(all_data1.dtypes)
# Out:
# id                      int64
# created_at             object
# item_name              object
# level                  object
# node_location_x         int64
# node_location_y         int64
# detected_node           int64
# radius_meter          float64
# visitor_location_x      int64
# visitor_location_y      int64
# dtype: object

# %%
visitor_1=all_data1[all_data1.item_name=='Visitor_1']
visitor_2=all_data1[all_data1.item_name=='Visitor_2']
visitor_3=all_data1[all_data1.item_name=='Visitor_3']
visitor_4=all_data1[all_data1.item_name=='Visitor_4']
visitor_5=all_data1[all_data1.item_name=='Visitor_5']
visitor_6=all_data1[all_data1.item_name=='Visitor_6']
visitor_7=all_data1[all_data1.item_name=='Visitor_7']
visitor_8=all_data1[all_data1.item_name=='Visitor_8']
visitor_9=all_data1[all_data1.item_name=='Visitor_9']
visitor_10=all_data1[all_data1.item_name=='Visitor_10']
visitors=[visitor_1,visitor_2,visitor_3,visitor_4,visitor_5,visitor_6,visitor_7,visitor_8,visitor_9,visitor_10]
for i in visitors:
    i.sort_values('id',inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10312\957563388.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   i.sort_values('id',inplace=True)

# %%
may_10=all_data1[all_data1.created_at.str.match('2023-05-10')]
may_11=all_data1[all_data1.created_at.str.match('2023-05-11')]
may_12=all_data1[all_data1.created_at.str.match('2023-05-12')]
may_13=all_data1[all_data1.created_at.str.match('2023-05-13')]
may_14=all_data1[all_data1.created_at.str.match('2023-05-14')]
may_15=all_data1[all_data1.created_at.str.match('2023-05-15')]
may_16=all_data1[all_data1.created_at.str.match('2023-05-16')]
may_17=all_data1[all_data1.created_at.str.match('2023-05-17')]
may_18=all_data1[all_data1.created_at.str.match('2023-05-18')]
may_19=all_data1[all_data1.created_at.str.match('2023-05-19')]
may_20=all_data1[all_data1.created_at.str.match('2023-05-20')]
detect_may_10=may_10.id.count()
detect_may_11=may_11.id.count()
detect_may_12=may_12.id.count()
detect_may_13=may_13.id.count()
detect_may_14=may_14.id.count()
detect_may_15=may_15.id.count()
detect_may_16=may_16.id.count()
detect_may_17=may_17.id.count()
detect_may_18=may_18.id.count()
detect_may_19=may_19.id.count()
detect_may_20=may_20.id.count()
detect_v1=visitor_1.id.count()
detect_v2=visitor_2.id.count()
detect_v3=visitor_3.id.count()
detect_v4=visitor_4.id.count()
detect_v5=visitor_5.id.count()
detect_v6=visitor_6.id.count()
detect_v7=visitor_7.id.count()
detect_v8=visitor_8.id.count()
detect_v9=visitor_9.id.count()
detect_v10=visitor_10.id.count()

# %% [markdown]
# ACTIVITY OF  DEETCTION SEPERATED BY DAYS

# %%
# Dayname=np.arange(10,21)
# DetectByDay=[detect_may_10,
#              detect_may_11,
#              detect_may_12,
#              detect_may_13,
#              detect_may_14,
#              detect_may_15,
#              detect_may_16,
#              detect_may_17,
#              detect_may_18,
#              detect_may_19,
#              detect_may_20,
#              ]
# color=['green','orange','cyan','purple','red','yellow','pink']
# plt.title('DETECTION ACTIVITIES EACH DAY MAY 10 TO MAY 20')
# plt.bar(Dayname,DetectByDay,color=color)
# plt.xlabel('MAY')
# plt.ylabel('DETECTION')
# plt.plot()
# Out:
# []

# %% [markdown]
# ACTIVITY OF VISITOR NUMBER FROM 10 MAY TO 20 MAY

# %%
# visitor_number=np.arange(1,11)
# DetectByVisitor=[detect_v1,
#                  detect_v2,
#                  detect_v3,
#                  detect_v4,
#                  detect_v5,
#                  detect_v6,
#                  detect_v7,
#                  detect_v8,
#                  detect_v9,
#                  detect_v10,]
# plt.title('VISITOR NUMBER DETECTION  MAY 10 TO MAY 20')
# plt.bar(visitor_number,DetectByVisitor)
# plt.xlabel('VISITOR NUMBER')
# plt.ylabel('DETECTION')
# plt.plot()
# Out:
# []

# %% [markdown]
# INFORMATION ABOUT VISITOR_1 , MAY 10 2023

# %%
may_10_v1=may_10[may_10.item_name=='Visitor_1']
may_10_v1_group_by_created=may_10_v1.groupby('created_at')
may_10_v1_group_by_created
